# %%
# !pip install ipytest  # 나는 % pip~로 설치함

# %%
import ipytest
ipytest.autoconfig()

# %%
# a program that adds two numbers

def add(a, b):
    return a + b


# unit test to determine if program works
assert add(2, 3) == 5

# %%
# create a program that asks for the user's age
# the program will return true, if the user is an adult

def get_user_age():
    return int(input("Enter age: ")) >= 18

assert get_user_age() == True

# %%
# %%ipytest
#
#
#
# # functions start with "test_"
# # contains asserts that are testing a single aspect of the program
# def test_number_assumptions():
#     age = 25
#
#     # check to see if the age is a particular value
#     assert age == 25
#
#     # check to see if the age is over 18
#     assert age > 18
#
#     # check to see if the age is under 100
#     assert age < 100
# Out:
# .                                                                                            [100%]
# 1 passed in 0.02s

# %%
# %%ipytest
#
# def test_something():
#     assert True
# Out:
# .                                                                                            [100%]
# 1 passed in 0.01s

# %%
# %%ipytest
#
# def test_something():
#     assert True
# Out:
# .                                                                                            [100%]
# 1 passed in 0.01s

# %%
# code to test

def get_list_of_colours():
    return ["red", "blue", "green"]

# %%
# %%ipytest
# # pytest functions
#
# def test_list_contents():
#     colors = get_list_of_colours()
#
#     assert colors[0] == "red"
# Out:
# .                                                                                            [100%]
# 1 passed in 0.02s

# %%
# %%ipytest
#
# # special asserts
# def test_special_asserts():
#     assert 1 < 2, "1 should be less than 2"
#     assert 2.45 > 1.23, "big decimals are greater than little decimals"
#     assert len("Hello World!") > 0, "the string's length should be > 0"
#
#     my_dict = {
#         "name": "John",
#         "id": "W213456"
#     }
#     assert my_dict["name"] == "John", "John is my name too...."
#     assert "W" in my_dict["id"], "the id should have a W"
#     assert "id" in my_dict, "the info should have an id"
# Out:
# .                                                                                            [100%]
# 1 passed in 0.01s

# %%
# !pip install pytest-mock
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytest-mock
#   Downloading pytest_mock-3.15.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pytest>=6.2.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest-mock) (8.4.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest>=6.2.5->pytest-mock) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest>=6.2.5->pytest-mock) (2.3.0)
# Requirement already satisfied: packaging>=20 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest>=6.2.5->pytest-mock) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest>=6.2.5->pytest-mock) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pytest>=6.2.5->pytest-mock) (2.19.2)
# Downloading pytest_mock-3.15.1-py3-none-any.whl (10 kB)
# Installing collected packages: pytest-mock
# Successfully installed pytest-mock-3.15.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %%ipytest
#
# # mocking
# def test_mocking(mocker):
#     mocker.patch('builtins.input', return_value="Goodbye World!")
#
#     user_input = input("Enter something: ")
#
#     assert(user_input == "Hello World!")
#
#     print(f"You typed: {user_input}")
# Out:
# E                                                                                            [100%]
# ============================================= ERRORS ==============================================
# _________________________________ ERROR at setup of test_mocking __________________________________
# file C:\Users\HP\AppData\Local\Temp\ipykernel_21976\2687812561.py, line 2
#   def test_mocking(mocker):
# E       fixture 'mocker' not found
# >       available fixtures: anyio_backend, anyio_backend_name, anyio_backend_options, cache, capfd, capfdbinary, caplog, capsys, capsysbinary, capteesys, doctest_namespace, free_tcp_port, free_tcp_port_factory, free_udp_port, free_udp_port_factory, monkeypatch, pytestconfig, record_property, record_testsuite_property, record_xml_attribute, recwarn, tmp_path, tmp_path_factory, tmpdir, tmpdir_factory
# >       use 'pytest --fixtures [testpath]' for help on them.
#
# C:\Users\HP\AppData\Local\Temp\ipykernel_21976\2687812561.py:2
# ===================================== short test summary info =====================================
# ERROR t_49b9af0f6aa3437abdf21b1fae2d3b04.py::test_mocking
# 1 error in 0.02s
